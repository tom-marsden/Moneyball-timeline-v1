# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
# Imports founder features dataset. Edit file path as necessary
features = pd.read_csv('data/features.csv')
features.head()
# Out:
#          age  PhD  Master's  CS  Maths  Chem  Business  Management  Marketing  \
# 0  33.778082    0         1   1      0     0         0           0          0
# 1  27.778082    0         0   0      0     0         0           0          0
# 2  24.778082    0         0   0      0     0         0           0          0
# 3  37.778082    0         0   0      0     0         0           0          0
# 4  32.778082    0         0   0      0     0         0           0          0
#
#    Bio  ...  numDegrees  avLengthJob  avLengthDegree  timeToFound  \
# 0    0  ...           1     1.957650             6.0          5.0
# 1    0  ...           1     1.584247             3.0          7.0
# 2    0  ...           1     1.001145             4.0          3.0
# 3    0  ...           2     2.685460             5.0         21.0
# 4    0  ...           4     3.388026             2.5         16.0
#
#    timeFromLastEd  timeFromFirstJob  timeFromLastJob  unemployedTime  \
# ...

# %%
# Extracts successful founder data
success = features[features['success'] == 1]
success.head()
# Out:
#          age  PhD  Master's  CS  Maths  Chem  Business  Management  Marketing  \
# 0  33.778082    0         1   1      0     0         0           0          0
# 1  27.778082    0         0   0      0     0         0           0          0
# 2  24.778082    0         0   0      0     0         0           0          0
# 3  37.778082    0         0   0      0     0         0           0          0
# 4  32.778082    0         0   0      0     0         0           0          0
#
#    Bio  ...  numDegrees  avLengthJob  avLengthDegree  timeToFound  \
# 0    0  ...           1     1.957650             6.0          5.0
# 1    0  ...           1     1.584247             3.0          7.0
# 2    0  ...           1     1.001145             4.0          3.0
# 3    0  ...           2     2.685460             5.0         21.0
# 4    0  ...           4     3.388026             2.5         16.0
#
#    timeFromLastEd  timeFromFirstJob  timeFromLastJob  unemployedTime  \
# ...

# %%
# Extracts unsuccessful founder data
fail = features[features['success'] == 0]
fail.head()
# Out:
#             age  PhD  Master's  CS  Maths  Chem  Business  Management  \
# 3865  53.778082    0         0   0      0     0         0           0
# 3866  43.778082    0         0   0      0     0         0           0
# 3867  28.778082    0         0   0      0     0         0           0
# 3868  28.778082    0         0   0      0     0         0           0
# 3869  25.778082    0         0   0      0     0         0           0
#
#       Marketing  Bio  ...  numDegrees  avLengthJob  avLengthDegree  \
# 3865          0    0  ...           0     4.226712        4.000000
# 3866          0    0  ...           0     8.861489        4.000000
# 3867          0    0  ...           3     3.232877        1.000000
# 3868          0    0  ...           3     2.097832        2.978825
# 3869          0    0  ...           0     1.354222        4.000000
#
#       timeToFound  timeFromLastEd  timeFromFirstJob  timeFromLastJob  \
# ...

# %% [markdown]
# ##Age:

# %%
# All histogram plots follow similar method

# Creates two plots in same image
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

# np.arange controls bin size for histogram
axes[0].hist(success['age'], density = True, bins = np.arange(0,90,5))
# Formatting
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,80)
axes[0].set_ylim(0,0.07)
axes[0].set_xlabel('Age in Years')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Age of Founders on Founding Date (Successful)', pad = 10)

axes[1].hist(fail['age'], density = True, bins = np.arange(0,90,5))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,80)
axes[1].set_ylim(0,0.07)
axes[1].set_xlabel('Age in Years')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Age of Founders on Founding Date (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)

# high peaks in centre due to missing data being placed at the mean

# %% [markdown]
# ##Number of Jobs

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

axes[0].hist(success['numJobs'], density = True, bins = np.arange(0,26,1))
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,25)
axes[0].set_xlabel('Number of Jobs')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Jobs Held before Founding Date (Successful)', pad = 10)

axes[1].hist(fail['numJobs'], density = True, bins = np.arange(0,26,1))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,25)
axes[1].set_xlabel('Number of Jobs')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Jobs Held before Founding Date (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# ##Number of Degrees

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

axes[0].hist(success['numDegrees'], density = True, bins = np.arange(0,25,1))
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,10)
axes[0].set_ylim(0,0.35)
axes[0].set_xlabel('Number of Educations')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Educations before Founding Date (Successful)', pad = 10)

axes[1].hist(fail['numDegrees'], density = True, bins = np.arange(0,25,1))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,10)
axes[1].set_ylim(0,0.35)
axes[1].set_xlabel('Number of Educations')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Educations before Founding Date (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# ##Average Job Length

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

axes[0].hist(success['avLengthJob'], density = True, bins = np.arange(0,25,0.5))
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,25)
axes[0].set_ylim(0,0.3)
axes[0].set_xlabel('Average Job Length')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Average Job Length (Successful)', pad = 10)

axes[1].hist(fail['avLengthJob'], density = True, bins = np.arange(0,25,0.5))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,25)
axes[1].set_ylim(0,0.3)
axes[1].set_xlabel('Average Job Length')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Average Job Length (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# ##Average Degree Length

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

axes[0].hist(success['avLengthDegree'], density = True, bins = np.arange(0,25,1))
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,15)
axes[0].set_xticks(np.arange(0,15,2))
axes[0].set_xlabel('Average Education Length')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Average Education Length (Successful)', pad = 10)

axes[1].hist(fail['avLengthDegree'], density = True, bins = np.arange(0,25,1))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,15)
axes[1].set_xticks(np.arange(0,15,2))
axes[1].set_xlabel('Average Education Length')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Average Education Length (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)
# peak at 0 for profiles without education data listed

# %% [markdown]
# ##Time to Found

# %%
fig, axes = plt.subplots(4, 2, figsize=(10, 16), dpi=300, facecolor='w')

axes[0,0].hist(success['timeToFound'], density = True, bins = np.arange(0,50,1))
axes[0,0].spines.right.set_visible(False)
axes[0,0].spines.top.set_visible(False)
axes[0,0].set_xlim(0,50)
axes[0,0].set_ylim(0,0.21)
axes[0,0].set_xlabel('Time from First Education to Founding')
axes[0,0].set_ylabel('Probability Density')
axes[0,0].set_title('Time from First Education to Founding', pad = 10)

axes[0,1].hist(fail['timeToFound'], density = True, bins = np.arange(0,50,1))
axes[0,1].spines.right.set_visible(False)
axes[0,1].spines.top.set_visible(False)
axes[0,1].set_xlim(0,50)
axes[0,1].set_ylim(0,0.21)
axes[0,1].set_xlabel('Time from First Education to Founding')
axes[0,1].set_ylabel('Probability Density')
axes[0,1].set_title('Time from First Education to Founding (Unsuccessful)', pad = 10)

axes[1,0].hist(success['timeFromLastEd'], density = True, bins = np.arange(0,50,1))
axes[1,0].spines.right.set_visible(False)
axes[1,0].spines.top.set_visible(False)
axes[1,0].set_xlim(0,40)
axes[1,0].set_ylim(0,0.35)
axes[1,0].set_xlabel('Time from Last Education to Founding')
axes[1,0].set_ylabel('Probability Density')
axes[1,0].set_title('Time from Last Education to Founding', pad = 10)

axes[1,1].hist(fail['timeFromLastEd'], density = True, bins = np.arange(0,50,1))
axes[1,1].spines.right.set_visible(False)
axes[1,1].spines.top.set_visible(False)
axes[1,1].set_xlim(0,40)
axes[1,1].set_ylim(0,0.35)
axes[1,1].set_xlabel('Time from Last Education to Founding')
axes[1,1].set_ylabel('Probability Density')
axes[1,1].set_title('Time from Last Education to Founding (Unsuccessful)', pad = 10)

axes[2,0].hist(success['timeFromFirstJob'], density = True, bins = np.arange(0,50,1))
axes[2,0].spines.right.set_visible(False)
axes[2,0].spines.top.set_visible(False)
axes[2,0].set_xlim(0,50)
axes[2,0].set_ylim(0,0.08)
axes[2,0].set_xlabel('Time from First Job to Founding')
axes[2,0].set_ylabel('Probability Density')
axes[2,0].set_title('Time from First Job to Founding', pad = 10)

axes[2,1].hist(fail['timeFromFirstJob'], density = True, bins = np.arange(0,50,1))
axes[2,1].spines.right.set_visible(False)
axes[2,1].spines.top.set_visible(False)
axes[2,1].set_xlim(0,50)
axes[2,1].set_ylim(0,0.08)
axes[2,1].set_xlabel('Time from First Job to Founding')
axes[2,1].set_ylabel('Probability Density')
axes[2,1].set_title('Time from First Job to Founding (Unsuccessful)', pad = 10)

axes[3,0].hist(success['timeFromLastJob'], density = True, bins = np.arange(0,50,1))
axes[3,0].spines.right.set_visible(False)
axes[3,0].spines.top.set_visible(False)
axes[3,0].set_xlim(0,5)
axes[3,0].set_xlabel('Time from Last Job to Founding')
axes[3,0].set_ylabel('Probability Density')
axes[3,0].set_title('Time from Last Job to Founding', pad = 10)

axes[3,1].hist(fail['timeFromLastJob'], density = True, bins = np.arange(0,50,1))
axes[3,1].spines.right.set_visible(False)
axes[3,1].spines.top.set_visible(False)
axes[3,1].set_xlim(0,5)
axes[3,1].set_xlabel('Time from Last Job to Founding')
axes[3,1].set_ylabel('Probability Density')
axes[3,1].set_title('Time from Last Job to Founding (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5, hspace = 0.5)
# peak at 0 for profiles without education data listed

# %% [markdown]
# ##Time Unemployed

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

axes[0].hist(success['unemployedTime'], density = True, bins = np.arange(0,25,1))
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,20)
axes[0].set_xlabel('Time Unemployed in Years')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Time Spent not Studying or Working (Successful)', pad = 10)

axes[1].hist(fail['unemployedTime'], density = True, bins = np.arange(0,25,1))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,20)
axes[1].set_xlabel('Time Unemployed in Years')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Time Spent not Studying or Working (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)
# peak at 0 for profiles without education data listed

# %% [markdown]
# ##Number of jobs at time of founding

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=300, facecolor='w')

axes[0].hist(success['simulJobs'], density = True, bins = np.arange(0,25,1))
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].set_xlim(0,10)
axes[0].set_ylim(0,0.5)
axes[0].set_xlabel('Number of Jobs')
axes[0].set_ylabel('Probability Density')
axes[0].set_title('Number of Jobs at Time of Founding (Successful)', pad = 10)

axes[1].hist(fail['simulJobs'], density = True, bins = np.arange(0,25,1))
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].set_xlim(0,10)
axes[1].set_ylim(0,0.5)
axes[1].set_xlabel('Number of Jobs')
axes[1].set_ylabel('Probability Density')
axes[1].set_title('Number of Jobs at Time of Founding (Unsuccessful)', pad = 10)

plt.subplots_adjust(wspace = 0.5)
# peak at 0 for profiles without education data listed

# %% [markdown]
# ##Degree subject

# %%
len_success = len(success)
len_fail = len(fail)
success_degrees = []
fail_degrees = []
index = []

# i goes over indexes of degree subjects in dataframes
for i in range(3,10):
  # Degree subject features one-hot encoded
  # Sums over relevant column for degree subject and converts into % of total
  success_degrees.append(success.iloc[:,i].sum()/len_success*100)
  fail_degrees.append(fail.iloc[:,i].sum()/len_fail*100)
  # Appends column title (name of degree subject)
  index.append(success.columns[i])

# Plots bar chart
fig, ax = plt.subplots(1, 1, figsize = (8,4), dpi = 300, facecolor='w')
# +- 0.2 and width values set for bars to be correctly spaced
ax.bar(np.arange(len(index)) - 0.2, success_degrees, width = 0.4, align='center', label = 'Successful')
ax.bar(np.arange(len(index)) + 0.2, fail_degrees, width = 0.4, color='r', align='center', label = 'Unsuccessful')

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
ax.set_ylabel('Percent of Founders')
ax.set_title('Percent of Founders Studying Each Degree', pad = 10)
ax.set_xticks(np.arange(len(index)), index)
ax.tick_params(labelsize = 8)
ax.yaxis.set_major_formatter(PercentFormatter(decimals = 0))
ax.legend(loc='upper right', ncols=2)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##Degree Type

# %%
# As above but with degree type (PhD, Master's)

len_success = len(success)
len_fail = len(fail)
success_degrees = []
index = []
fail_degrees = []

for i in range(1,3):
  success_degrees.append(success.iloc[:,i].sum()/len_success*100)
  fail_degrees.append(fail.iloc[:,i].sum()/len_fail*100)
  index.append(success.columns[i])

fig, ax = plt.subplots(1, 1, figsize = (8,4), dpi = 300, facecolor='w')
ax.bar([0.2, 0.5], success_degrees, width = 0.1, align='center', label = 'Successful')
ax.bar([0.3, 0.6], fail_degrees, width = 0.1, color='r', align='center', label = 'Unsuccessful')

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
ax.set_ylabel('Percent of Founders')
ax.set_title('Percent of Founders with Each Type of Degree', pad = 10)
ax.set_xticks([0.25, 0.55], index)
ax.yaxis.set_major_formatter(PercentFormatter(decimals = 0))
ax.legend(loc='upper left', ncols=2)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
